# %%
import pandas as pd

# %%
df=pd.read_csv('data1.csv')
df
# Out:
#        State Name  RICE AREA (1000 ha)  RICE PRODUCTION (1000 tons)
# 0    Chhattisgarh               841.13                       983.21  \
# 1    Chhattisgarh               660.36                       801.82
# 2    Chhattisgarh               959.01                      1520.95
# 3    Chhattisgarh               727.94                      1295.71
# 4    Chhattisgarh               411.12                       623.29
# ..            ...                  ...                          ...
# 305     Jharkhand               266.02                       533.69
# 306     Jharkhand                53.28                       113.46
# 307     Jharkhand               121.89                       253.28
# 308     Jharkhand               556.33                      1124.50
# 309     Jharkhand               386.91                       669.97
#
#      WHEAT AREA (1000 ha)  WHEAT PRODUCTION (1000 tons)  MAIZE AREA (1000 ha)
# ...

# %%
df.columns
# Out:
# Index(['State Name', 'RICE AREA (1000 ha)', 'RICE PRODUCTION (1000 tons)',
#        'WHEAT AREA (1000 ha)', 'WHEAT PRODUCTION (1000 tons)',
#        'MAIZE AREA (1000 ha)', 'MAIZE PRODUCTION (1000 tons)',
#        'CHICKPEA AREA (1000 ha)', 'CHICKPEA PRODUCTION (1000 tons)',
#        'SUGARCANE AREA (1000 ha)', 'SUGARCANE PRODUCTION (1000 tons)',
#        'COTTON AREA (1000 ha)', 'COTTON PRODUCTION (1000 tons)'],
#       dtype='object')

# %%
df.columns=['state_name','rice_area','rice_prod','wheat_area','wheat_prod','maize_area','maize_prod','chickpea_area','chickpea_prod','sugarcane_area','sugarcane_prod','cotton_area','cotton_prod']

# %%
df
# Out:
#        state_name  rice_area  rice_prod  wheat_area  wheat_prod  maize_area
# 0    Chhattisgarh     841.13     983.21       43.50       50.19        9.25  \
# 1    Chhattisgarh     660.36     801.82        1.24        2.22       41.94
# 2    Chhattisgarh     959.01    1520.95       14.56       23.66        6.13
# 3    Chhattisgarh     727.94    1295.71       15.80       21.72        7.61
# 4    Chhattisgarh     411.12     623.29        3.91        6.76        6.29
# ..            ...        ...        ...         ...         ...         ...
# 305     Jharkhand     266.02     533.69        0.00        0.00       64.33
# 306     Jharkhand      53.28     113.46        0.00        0.00        4.95
# 307     Jharkhand     121.89     253.28        0.00        0.00       66.32
# 308     Jharkhand     556.33    1124.50        0.00        0.00       39.61
# 309     Jharkhand     386.91     669.97        0.00        0.00       27.07
#
# ...

# %%
df1=df.groupby(['state_name']).sum()

# %%
df1.head()
# Out:
#                 rice_area  rice_prod  wheat_area  wheat_prod  maize_area
# state_name
# Andhra Pradesh    2218.18    8461.34        0.05        0.04      336.53  \
# Assam             2417.18    5255.40       17.58       24.39       31.39
# Bihar             3306.98    8093.16     2101.31     6104.30      677.45
# Chhattisgarh      3976.63    5749.05      102.19      141.64      119.62
# Gujarat            855.29    1889.81     1058.76     3101.06      399.99
#
#                 maize_prod  chickpea_area  chickpea_prod  sugarcane_area
# state_name
# Andhra Pradesh     2325.90         520.38         589.13           98.92  \
# Assam                98.30           2.22           1.52           30.52
# Bihar              3120.75          58.22          67.18          233.77
# Chhattisgarh        306.95         335.02         331.68           34.84
# Gujarat             714.76         292.77         376.26          181.70
#
#                 sugarcane_prod  cotton_area  cotton_prod
# ...

# %%
df_rice=df1[['rice_area','rice_prod']]
df_wheat=df1[['wheat_area','wheat_prod']]
df_maize=df1[['maize_area','maize_prod']]
df_chickpea=df1[['chickpea_area','chickpea_prod']]
df_sugarcane=df1[['sugarcane_area','sugarcane_prod']]
df_cotton=df1[['cotton_area','cotton_prod']]

# %%
rice=df_rice.sort_values(by=['rice_prod'],ascending=False).reset_index(drop=False).head().to_dict(orient='records')
wheat=df_wheat.sort_values(by=['wheat_prod'],ascending=False).reset_index(drop=False).head().to_dict(orient='records')
maize=df_maize.sort_values(by=['maize_prod'],ascending=False).reset_index(drop=False).head().to_dict(orient='records')
chickpea=df_chickpea.sort_values(by=['chickpea_prod'],ascending=False).reset_index(drop=False).head().to_dict(orient='records')
sugarcane=df_sugarcane.sort_values(by=['sugarcane_prod'],ascending=False).reset_index(drop=False).head().to_dict(orient='records')
cotton=df_cotton.sort_values(by=['cotton_prod'],ascending=False).head().reset_index(drop=False).to_dict(orient='records')

# %%
rice
# Out:
# [{'state_name': 'West Bengal',
#   'rice_area': 5307.6900000000005,
#   'rice_prod': 15658.94},
#  {'state_name': 'Uttar Pradesh', 'rice_area': 5937.08, 'rice_prod': 15551.39},
#  {'state_name': 'Punjab', 'rice_area': 3065.0, 'rice_prod': 13382.0},
#  {'state_name': 'Andhra Pradesh',
#   'rice_area': 2218.1800000000003,
#   'rice_prod': 8461.34},
#  {'state_name': 'Bihar', 'rice_area': 3306.98, 'rice_prod': 8093.16}]

# %%
import json
def writejson(file_name,chart_data):
    json_ob = json.dumps(chart_data,indent=2)
    with open(file_name,"w") as outfile:
        outfile.write(json_ob)

# %%
file_list = ['rice.json','wheat.json','maize.json','chickpea.json','sugarcane.json','cotton.json']
dict_list = [rice,wheat,maize,chickpea,sugarcane,cotton]
for i,j in zip(file_list,dict_list):
    writejson(i,j)
